# %% [markdown]
# # 测试 Conda 环境
#
# 点击右上角 **选择内核** → **Python Environments...** → 选择 `base (conda)`

# %%
import sys
print("Python 路径:", sys.executable)

# %%
# 测试常用包
import os
print("当前目录:", os.getcwd())
